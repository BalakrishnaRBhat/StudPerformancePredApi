# %%
# --------------------------------------------------
# Data Analysis - Part 1

import pandas as pd
import random

category = pd.read_excel('category_dataset.xls',usecols="A,B")
# print(category) 

data = pd.read_excel('sample3.xls')
# print(data)
df1 = data.drop(['Name','USN'],axis=1)
df2 = df1.transpose()
# print(df2)
# print(df1.columns.values)
binned = [random.randrange(1,10,1) for i in range(len(data))]
i = 0
for subject, column in df2.iteritems():
    binned[i] = pd.cut(column, bins=[-1,39,44,59,69,79,89,100], labels=[0,4,6,7,8,9,10])
    i = i + 1
# for item in binned:
#     print(item.tolist())
#     break
# print(binned)
count = 0
max_points = 0
total_column = list()
for item in binned:
    sum = 0
    j = 0
    for subject in df1.columns.values:
        for sub in range(len(category)):
            if(str(subject).lower() == str(category.loc[sub,"Subjects"]).lower()):
                sum = sum + category.loc[sub,"Credits"]*item.tolist()[j]
                if(count < len(df1.columns.values)):
                    max_points = max_points + category.loc[sub,"Credits"]
                    count = count + 1
                j =j + 1
                break
    total_column.append(sum)
# print(total_column)
# print(len(total_column))
# print(len(df))
max_points = max_points*10
# print(max_points)

df2 = df2.transpose()
df2["Total_points"] = total_column
# print(df2)
# df2.describe()

# df2.to_excel('student_dataset.xls')

# %%
# -------------------------------------------------------------------------
# Prediction 


d = df2
# print(data)

# import lazypredict
# from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import numpy as np
import math

X = d.iloc[:, :-1]
# print(X)
Y = d.iloc[:, -1]
# print(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25)

# clf = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
# models, predictions = clf.fit(X_train, X_test, Y_train, Y_test)
# print(models)
# print(predictions)

poly_feat = PolynomialFeatures(degree=1)
poly_X = poly_feat.fit_transform(X)
reg = LinearRegression()
reg.fit(poly_X, Y)
pred = reg.predict(poly_X)
# print(pred)

# lin_reg = LinearRegression()
# lin_reg.fit(X_train, Y_train)
# lin_pred = lin_reg.predict(X)
# print(lin_pred)

# from sklearn.metrics import r2_score, mean_squared_error
# rmse = np.sqrt(mean_squared_error(Y, pred))
# r2_score = r2_score(Y, pred)
# print("rmse:",rmse)
# print("r2_score:",r2_score)

# %%
# -----------------------------------------------------------------
# Data Analysis - Part 2

# pred variable contains predicted targeted points


prediction_points = list()
for points in pred:
    prediction_points.append(int(round(points, 0)))
# print(prediction_points)

# df = pd.DataFrame()
# print(df)

# import statistics as st

# l0 = list()
# for i in range(0,40):
#     l0.append(i)
# print(l0)
# m0 = st.median(l0)

# l4 = list()
# for i in range(40,45):
#     l4.append(i)
# print(l4)
# m4 = st.median(l4)

# l6 = list()
# for i in range(45,60):
#     l6.append(i)
# print(l6)
# m6 = st.median(l6)

# l7 = list()
# for i in range(60,70):
#     l7.append(i)
# print(l7)
# m7 = st.median(l7)

# l8 = list()
# for i in range(70,80):
#     l8.append(i)
# print(l8)
# m8 = st.median(l8)

# l9 = list()
# for i in range(80,90):
#     l9.append(i)
# print(l9)
# m9 = st.median(l9)

# l10 = list()
# for i in range(90,101):
#     l10.append(i)
# print(l10)
# m10 = st.median(l10)
# print(m0, m4, m6, m7, m8, m9, m10)

# l = [20, 42, 52, 65, 75, 85, 95]

columns2 = ['Transform Calculus, Fourier Series And Numerical Techniques','Data Structures and Applications','Analog and Digital Electronics','Computer Organization','Software Engineering','Discrete Mathematical Structures','Analog and Digital Electronics Laboratory','Data Structures Laboratory','Constitution of India, Professional Ethics and Cyber Law']
columns3 = ['Advanced Calculus And Numerical Methods','Engineering Chemistry','C Programming For Problem Solving','Basic Electronics','Elements Of Mechanical Engineering','Engineering Chemistry Laboratory','C Programming Laboratory','Technical English 2']

student = list()
for points in prediction_points:
    if(points < 0):
        points = 0
    elif(points > max_points):
        points = max_points
    for subject in columns3:
        for i in range(len(category)):
            if(str(subject).lower() == str(category.loc[i,"Subjects"]).lower()):
                if((math.ceil((points/len(columns3))/category.loc[i,"Credits"]) == 0) or (math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 1) or (math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 2) or (math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 3)):
                    marks = 20
                elif((math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 4)):
                    marks = 42
                elif((math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 5) or (math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 6)):
                    marks = 52
                elif((math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 7)):
                    marks = 65
                elif((math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 8)):
                    marks = 75
                elif((math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 9)):
                    marks = 85
                elif((math.ceil((points/(len(columns3)))/category.loc[i,"Credits"]) == 10)):
                    marks = 95
                student.append(marks)
#     students.append(student)
# print(student)

name_column = list(data.iloc[:,0])
usn_column = list(data.iloc[:, 1])
# print(name_column, usn_column)
header_column = list()
header_column.append('Name')
header_column.append('USN')
for i in columns3:
    header_column.append(i)
# print(header_column)

pred_df = pd.DataFrame(np.random.rand(len(name_column), len(header_column)), columns=header_column)
# print(pred_df)

students = {header:0 for header in header_column}
i = 0
j = 0
while(i<len(student)):
    for header in header_column:
        if(header == 'Name'):
            students.update({header:name_column[j]})
        elif(header == 'USN'):
            students.update({header:usn_column[j]})
        else:
            students.update({header:student[i]})
            i = i + 1
    pred_df.iloc[j] = students.values()
    j = j + 1

for i in columns3:
    pred_df[[i]] = pred_df[[i]].astype(int)
# print(pred_df)

# pred_df.to_excel('predicted_student_dataset.xls')
